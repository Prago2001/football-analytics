# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Pitch, 
from pathlib import Path

# %%
MATCH_DIR = Path("../data/matches").glob("*/")
MATCH_DIR = sorted(MATCH_DIR)

# %%
qualifiers = pd.read_parquet(f"{MATCH_DIR[32]}/qualifiers.parquet")
events = pd.read_parquet(f"{MATCH_DIR[32]}/events.parquet")
meta   = pd.read_parquet(f"{MATCH_DIR[32]}/metadata.parquet")

qualifiers.info(), events.info(), meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8176 entries, 0 to 8175
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   event_id        8176 non-null   int64
#  1   qualifier_id    8176 non-null   int64
#  2   qualifier_name  8176 non-null   object
#  3   qualifier_desc  8176 non-null   object
#  4   value           6666 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 319.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1740 entries, 0 to 1739
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1740 non-null   int64
#  1   match_id     1740 non-null   object
#  2   type_id      1740 non-null   int64
#  3   type_name    1740 non-null   object
#  4   period_id    1740 non-null   int64
#  5   minute       1740 non-null   int64
#  6   second       1740 non-null   int64
# ...

# %%
shots = events.loc[events["type_name"].isin(["Attempt Saved", "Miss", "Goal","Post"])]

# %%
shot_qualfiers = qualifiers[
    qualifiers["event_id"].isin(shots["id"].unique())
].sort_values(by=["event_id", "qualifier_id"])
# Out:
#        event_id  qualifier_id           qualifier_name  \
# 533  2935136635            18        Out of box centre
# 535  2935136635            20             Right footed
# 526  2935136635            22             Regular play
# 528  2935136635            29                 Assisted
# 524  2935136635            55         Related event ID
# 530  2935136635            56                     Zone
# 532  2935136635            84          Close low right
# 534  2935136635           102  Goal mouth y coordinate
# 523  2935136635           103  Goal mouth z coordinate
# 529  2935136635           120              Swerve left
# 531  2935136635           215          Individual play
# 527  2935136635           230          GK X coordinate
# 525  2935136635           231          GK Y coordinate
# 699  2935138429            17               Box centre
# 702  2935138429            20             Right footed
#
#                                         qualifier_desc   value
# ...

# %%
shots
# Out:
#               id                   match_id  type_id      type_name  \
# 114   2935136635  50o32ylys1nykzuao8kko9ams       13           Miss
# 150   2935138429  50o32ylys1nykzuao8kko9ams       15  Attempt Saved
# 164   2935140027  50o32ylys1nykzuao8kko9ams       13           Miss
# 183   2935141847  50o32ylys1nykzuao8kko9ams       13           Miss
# 191   2935143217  50o32ylys1nykzuao8kko9ams       15  Attempt Saved
# 327   2935152671  50o32ylys1nykzuao8kko9ams       15  Attempt Saved
# 329   2935152705  50o32ylys1nykzuao8kko9ams       15  Attempt Saved
# 405   2935157891  50o32ylys1nykzuao8kko9ams       15  Attempt Saved
# 478   2935163327  50o32ylys1nykzuao8kko9ams       13           Miss
# 554   2935167007  50o32ylys1nykzuao8kko9ams       13           Miss
# 600   2935169299  50o32ylys1nykzuao8kko9ams       15  Attempt Saved
# 673   2935175327  50o32ylys1nykzuao8kko9ams       15  Attempt Saved
# 804   2935183439  50o32ylys1nykzuao8kko9ams       15  Attempt Saved
# ...
